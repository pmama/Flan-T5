# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#!pip install -U langchain

# %%
#!pip install -U huggingface-hub

# %%
import os
token = "use your hf_api_token"
os.environ["HUGGINGFACEHUB_API_TOKEN"]= token

# %%
from langchain.llms import HuggingFaceHub

# %% [markdown]
# # Flan-T5- large Model
# ![image.png](attachment:image.png)

# %%
llm = HuggingFaceHub(repo_id='google/flan-t5-large')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
our_query ="What is the currency of India?"
completion = llm(our_query)
print(completion)
# Out:
# rupee

# %%
our_query ="What is the current capital of India?"
completion = llm(our_query)
print(completion)
# Out:
# chennai

# %%
our_query ="What is the capital of Japan?"
completion = llm(our_query)
print(completion)
# Out:
# tokyo

# %%
our_query ="What is the Langchain?"
completion = llm(our_query)
print(completion)
# Out:
# lincolnshire

# %%
our_query ="who is the prime minister of India?"
completion = llm(our_query)
print(completion)
# Out:
# Narendra Modi

# %%
our_query ="Who created  flan-T5?"
completion = llm(our_query)
print(completion)
# Out:
# dr. edward edwin edwin
